# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarsh6174/ML/blob/main/21_eda_using_multivariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
titanic = pd.read_csv('/content/train (1) titanic.csv')
flights = sns.load_dataset('flights')
iris = sns.load_dataset('iris')

# %%
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 18        16.97  3.50  Female     No   Sun  Dinner     3
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 218        7.74  1.44    Male    Yes   Sat  Dinner     2
# 36        16.31  2.00    Male     No   Sat  Dinner     3
# 118       12.43  1.80  Female     No  Thur   Lunch     2

# %%
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 352          353         0       3            Elias, Mr. Tannous  male  15.0
# 86            87         0       3        Ford, Mr. William Neal  male  16.0
# 624          625         0       3   Bowen, Mr. David John "Dai"  male  21.0
# 285          286         0       3           Stankovic, Mr. Ivan  male  33.0
# 545          546         0       1  Nicholson, Mr. Arthur Ernest  male  64.0
#
#      SibSp  Parch      Ticket     Fare Cabin Embarked
# 352      1      1        2695   7.2292   NaN        C
# 86       1      3  W./C. 6608  34.3750   NaN        S
# 624      0      0       54636  16.1000   NaN        S
# 285      0      0      349239   8.6625   NaN        C
# 545      0      0         693  26.0000   NaN        S

# %%
flights.sample(5)
# Out:
#      year month  passengers
# 82   1955   Nov         237
# 94   1956   Nov         271
# 93   1956   Oct         306
# 2    1949   Mar         132
# 100  1957   May         355

# %%
iris.sample(5)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 73           6.1          2.8           4.7          1.2  versicolor
# 88           5.6          3.0           4.1          1.3  versicolor
# 72           6.3          2.5           4.9          1.5  versicolor
# 26           5.0          3.4           1.6          0.4      setosa
# 45           4.8          3.0           1.4          0.3      setosa

# %% [markdown]
# 1. Scatterplot (numerical - numerical)

# %%
sns.scatterplot(x=tips['total_bill'],y=tips['tip'],hue = tips['sex'],style = tips['smoker'],size = df['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# 2.Bar Plot ( Numerical - categorical)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(x = titanic['Pclass'],y=titanic['Fare'],hue = titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# 3.Box PLot (numerical - categorical)

# %%
sns.boxplot(x = titanic['Sex'],y = titanic['Age'],hue = titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# 4.Distplot ( numerical  - categorical)

# %%
sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False,)
sns.distplot(titanic[titanic['Survived']==1]['Age'],hist = False)
# Out:
# /tmp/ipykernel_2874/1195397351.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False,)
# /tmp/ipykernel_2874/1195397351.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# 5.HeaMap ( categorical - categorical)

# %%
#number of people survived in pclass
pd.crosstab(titanic['Pclass'],titanic['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
#percentage
(titanic.groupby('Pclass')['Survived'].mean()*100)
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %% [markdown]
# 6.ClusterMap ( categorical  - categorical)

# %%
sns.clustermap(pd.crosstab(titanic['Parch'],titanic['Survived']))

# %% [markdown]
# 7.Pairplot(collection of scatterplot)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# 8.Lineplot ( numerical - numercial) . use when x axis time based .

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.heatmap(flights.pivot_table(values = 'passengers',index = 'month',columns='year'))
# Out:
# /tmp/ipykernel_2874/2813051871.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(values = 'passengers',index = 'month',columns='year'))
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# use clustermap for getting same behaviour adjacent

# %%
sns.clustermap(flights.pivot_table(values = 'passengers',index = 'month',columns='year'))
# Out:
# /tmp/ipykernel_2874/3995423183.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flights.pivot_table(values = 'passengers',index = 'month',columns='year'))
